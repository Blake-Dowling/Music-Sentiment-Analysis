# %%
'''
Sources:
sentiment analysis inspiration: https://www.kaggle.com/code/ekrembayar/f-r-i-e-n-d-s-text-mining-data-visualization
AFINN docs: https://github.com/fnielsen/afinn

Genius API docs: https://docs.genius.com/
Genius API tutorial: https://www.youtube.com/watch?v=cU8YH2rhN6A

'''

import os
import lyricsgenius
import json
from dotenv import load_dotenv
from pprint import pprint

load_dotenv()

genius_access_token = os.getenv('GENIUS_ACCESS_TOKEN')

genius = lyricsgenius.Genius(genius_access_token)

song = genius.search_song("zeze", "kodak black")
# Out:
# Searching for "zeze" by kodak black...
# Done.

# %%
pprint(song.__dict__, indent=4)
lyrics = song.lyrics
# Out:
# {   '_body': {   '_type': 'song',
#                  'annotation_count': 33,
#                  'api_path': '/songs/3995573',
#                  'artist_names': 'Kodak Black (Ft. Offset & Travis Scott)',
#                  'featured_artists': [   {   '_type': 'artist',
#                                              'api_path': '/artists/88813',
#                                              'header_image_url': 'https://images.genius.com/95855b9d1e854a06980aaff71acac630.801x1000x1.jpg',
#                                              'id': 88813,
#                                              'image_url': 'https://images.genius.com/266c8abf2c3323ab3a9ef1e7a75e41c1.1000x1000x1.jpg',
#                                              'index_character': 'o',
#                                              'iq': 805,
#                                              'is_meme_verified': False,
#                                              'is_verified': True,
# ...

# %%
artist = genius.artist(162126)
pprint(artist, indent=4)
# Out:
# {   'artist': {   'alternate_names': [   'Bill Kahan Kapri',
#                                          'Bill Kapri',
#                                          'Bill K. Kapri',
#                                          'Lil Kodak',
#                                          'Dieuson Octave'],
#                   'api_path': '/artists/162126',
#                   'current_user_metadata': {   'excluded_permissions': [   'edit',
#                                                                            'edit_images',
#                                                                            'edit_names',
#                                                                            'edit_anything',
#                                                                            'merge',
#                                                                            'sort_artist_songs',
#                                                                            'follow',
# ...
